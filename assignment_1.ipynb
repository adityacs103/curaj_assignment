# %%
import pandas as pd
import numpy as np
import seaborn as sns
data = pd.read_csv('https://raw.githubusercontent.com/adityacs103/assignment_1/main/daily_temp.csv')
# 1 understanding the data
data.head()
# Out:
#       temp      Name
# 0  42.8153    Lander
# 1  42.8153    Lander
# 2  41.1519  Cheyenne
# 3  41.1519  Cheyenne
# 4  44.9258    Wausau

# %%
data.shape
# Out:
# (400, 2)

# %%
data.describe()
# Out:
#              temp
# count  400.000000
# mean    38.907297
# std      5.586842
# min     24.555000
# 25%     35.181800
# 50%     40.200000
# 75%     42.789050
# max     48.561400

# %%
data.columns
# Out:
# Index(['temp', 'Name'], dtype='object')

# %%
data
# Out:
#         temp             Name
# 0    42.8153           Lander
# 1    42.8153           Lander
# 2    41.1519         Cheyenne
# 3    41.1519         Cheyenne
# 4    44.9258           Wausau
# ..       ...              ...
# 395  39.8328           Denver
# 396  39.8328           Denver
# 397  38.8100  ColoradoSprings
# 398  38.8100  ColoradoSprings
# 399  41.7803     CrescentCity
#
# [400 rows x 2 columns]

# %%
temp_data=list(data['temp'])
arr=np.array(temp_data)

# %%
final_data=arr.reshape(20,20)
print(final_data)
# Out:
# [[42.8153 42.8153 41.1519 41.1519 44.9258 44.9258 46.0261 46.0261 44.8664
#   44.8664 46.5486 46.5486 42.955  42.955  43.1406 43.1406 43.8789 43.8789
#   43.8789 43.8789]
#  [44.4983 37.2958 37.2958 39.6428 39.6428 40.1764 40.1764 38.365  38.365
#   38.365  38.3794 38.3794 38.3794 37.7836 37.7836 45.6208 45.6208 46.7439
#   46.7439 46.7439]
#  [46.2667 46.2667 47.6217 47.4444 47.4444 37.505  37.505  36.9033 36.9033
#   37.3208 37.3208 44.4683 44.4683 40.7781 40.7781 30.5892 30.5892 29.5442
#   29.5442 29.5442]
#  [29.98   29.98   29.2733 29.2733 31.8111 31.8111 32.8978 32.8978 32.8978
#   32.8978 27.8    27.8    30.3208 30.3208 35.2333 35.2333 32.4106 32.4106
#   36.1189 36.1189]
#  [35.0564 35.0564 35.0311 35.0311 43.7667 43.7667 43.5878 44.3981 45.4558
#   33.55   33.55   34.8461 34.8461 33.9486 33.9486 41.2433 41.2433 40.4847
#   40.4847 40.4847]
#  [39.8683 39.8683 40.1936 40.1936 40.1936 42.08   42.08   42.1469 42.1469
# ...

# %%
from numpy.linalg import eig
eigen_value,eigen_vector=eig(final_data)

# %%
print("Eigen value=\n",eigen_value)
# Out:
# Eigen value=
#  [ 7.78459342e+02 +0.j          1.38180792e+01 +0.j
#  -9.49447738e+00 +7.39675861j -9.49447738e+00 -7.39675861j
#   3.52879611e+00+11.39534636j  3.52879611e+00-11.39534636j
#   7.55730788e+00 +9.46812834j  7.55730788e+00 -9.46812834j
#  -9.50497674e+00 +0.j          5.77746039e+00 +4.73090286j
#   5.77746039e+00 -4.73090286j -3.20372770e+00 +4.35335057j
#  -3.20372770e+00 -4.35335057j  1.92272587e+00 +3.17387009j
#   1.92272587e+00 -3.17387009j -3.70680805e+00 +0.j
#  -1.21997363e+00 +1.99243762j -1.21997363e+00 -1.99243762j
#  -8.28043411e-01 +0.j          4.39184180e-01 +0.j        ]

# %%
print("Eigen vector=",eigen_vector)
# Out:
# Eigen vector= [[-0.25157203+0.j         -0.08328291+0.j         -0.07494451+0.09635483j
#   -0.07494451-0.09635483j  0.03930882+0.06480351j  0.03930882-0.06480351j
#    0.09382206+0.05309467j  0.09382206-0.05309467j -0.14210426+0.j
#    0.2247242 +0.02065874j  0.2247242 -0.02065874j -0.03074555-0.25290536j
#   -0.03074555+0.25290536j  0.09094904-0.05419791j  0.09094904+0.05419791j
#    0.3822129 +0.j          0.28594896-0.12423977j  0.28594896+0.12423977j
#   -0.21428796+0.j          0.09500107+0.j        ]
#  [-0.2322281 +0.j         -0.04884333+0.j          0.36671642-0.11759572j
#    0.36671642+0.11759572j -0.03316068+0.0654553j  -0.03316068-0.0654553j
#    0.0860344 +0.11441088j  0.0860344 -0.11441088j -0.28740306+0.j
#    0.12504638+0.14586199j  0.12504638-0.14586199j  0.05575435+0.1882556j
#    0.05575435-0.1882556j  -0.14164619+0.00190182j -0.14164619-0.00190182j
#   -0.24284908+0.j         -0.20988035+0.06833894j -0.20988035-0.06833894j
# ...
